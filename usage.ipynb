# %%
import tensorflow as tf
import numpy as np
import time
from cursor import Cursor
from pynput.mouse import Listener
import os
import pandas as pd
import cv2

model_name = "comfy-lion.h5"

class Webcam:
    def __init__(self):
        self.directory = ""
        self.cap = cv2.VideoCapture(0)

    def capture(self, id):
        """Take picture with the webcam and save the image under the directory stored in the attributes of the class with the passed id.

        Args:
            id (int): id of the picture
        """
        ret, frame = self.cap.read()

        if ret:
            filename = os.path.join(self.directory, f"{id}.jpg")
            cv2.imwrite(filename, frame)

    def release(self):
        """Release the webcam and destroy all windows."""
        self.cap.release()
        cv2.destroyAllWindows()

screen_x = 3840
screen_y = 2200

cursor = Cursor()
cam = Webcam()

model = tf.keras.models.load_model(model_name)

# def preprocess_image(image_path):
#     image = tf.io.read_file(image_path)
#     image = tf.image.decode_jpeg(image, channels=3)
#     image = tf.image.resize(image, (256, 256)) / 255.0
#     return tf.expand_dims(image, axis=0)  # Add batch dimension

# while True:
#     image_id = "42"
#     cam.capture(image_id)

#     image_path = f"{image_id}.jpg"
#     image = cv2.imread(image_path)
#     ... (preprocess here)
#     prediction = model.predict(image)
#     prediction = np.clip(prediction, 0.01, 0.99)

#     print("Predicted coordinates:", prediction[0])
#     cursor.set_position(prediction[0][0]*screen_x, prediction[0][1]*screen_y)
#     time.sleep(0.01)
#     # print("Prediction set")

while True:
    image_id = "42"
    cam.capture(image_id)

    image_path = f"{image_id}.jpg"
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # Preprocessing (matching training)
    # image = cv2.resize(image, (350, 350)) # Resize to 350x350
    image = image / 255.0 # normalization

    image_expanded = np.expand_dims(image, axis=(0, 3))

    # Prediction
    prediction = model.predict(image_expanded)
    prediction = np.clip(prediction, 0.01, 0.99)

    print("Predicted coordinates:", prediction[0])
    cursor.set_position(prediction[0][0] * screen_x, prediction[0][1] * screen_y)
    time.sleep(0.01)
# Out:
# 1/1 [==============================] - 0s 163ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 45ms/step
# Predicted coordinates: [0.99    0.01514]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99   0.1648]
# 1/1 [==============================] - 0s 60ms/step
# Predicted coordinates: [0.6357 0.285 ]
# 1/1 [==============================] - 0s 34ms/step
# Predicted coordinates: [0.5454 0.3403]
# 1/1 [==============================] - 0s 19ms/step
# Predicted coordinates: [0.5415 0.3577]
# 1/1 [==============================] - 0s 22ms/step
# Predicted coordinates: [0.5444 0.3506]
# 1/1 [==============================] - 0s 20ms/step
# Predicted coordinates: [0.5537 0.3323]
# 1/1 [==============================] - 0s 31ms/step
# Predicted coordinates: [0.558  0.3247]
# 1/1 [==============================] - 0s 48ms/step
# Predicted coordinates: [0.56   0.3213]
# 1/1 [==============================] - 0s 57ms/step
# Predicted coordinates: [0.5625 0.32  ]
# 1/1 [==============================] - 0s 33ms/step
# Predicted coordinates: [0.5635 0.3184]
# 1/1 [==============================] - 0s 28ms/step
# Predicted coordinates: [0.5635 0.3176]
# 1/1 [==============================] - 0s 30ms/step
# Predicted coordinates: [0.5645 0.3162]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.5645 0.3154]
# 1/1 [==============================] - 0s 49ms/step
# Predicted coordinates: [0.57   0.3086]
# 1/1 [==============================] - 0s 22ms/step
# Predicted coordinates: [0.5894 0.2952]
# 1/1 [==============================] - 0s 32ms/step
# Predicted coordinates: [0.6113 0.2905]
# 1/1 [==============================] - 0s 23ms/step
# Predicted coordinates: [0.6436 0.2832]
# 1/1 [==============================] - 0s 26ms/step
# Predicted coordinates: [0.664  0.2795]
# 1/1 [==============================] - 0s 57ms/step
# Predicted coordinates: [0.6797 0.2788]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.6978 0.274 ]
# 1/1 [==============================] - 0s 21ms/step
# Predicted coordinates: [0.709 0.27 ]
# 1/1 [==============================] - 0s 28ms/step
# Predicted coordinates: [0.726  0.2625]
# 1/1 [==============================] - 0s 32ms/step
# Predicted coordinates: [0.7334 0.259 ]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.743  0.2556]
# 1/1 [==============================] - 0s 23ms/step
# Predicted coordinates: [0.7485 0.2534]
# 1/1 [==============================] - 0s 29ms/step
# Predicted coordinates: [0.756  0.2507]
# 1/1 [==============================] - 0s 52ms/step
# Predicted coordinates: [0.7573 0.2502]
# 1/1 [==============================] - 0s 21ms/step
# Predicted coordinates: [0.756  0.2512]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.756  0.2515]
# 1/1 [==============================] - 0s 30ms/step
# Predicted coordinates: [0.754  0.2524]
# 1/1 [==============================] - 0s 32ms/step
# Predicted coordinates: [0.751 0.254]
# 1/1 [==============================] - 0s 22ms/step
# Predicted coordinates: [0.748  0.2551]
# 1/1 [==============================] - 0s 25ms/step
# Predicted coordinates: [0.7466 0.2559]
# 1/1 [==============================] - 0s 23ms/step
# Predicted coordinates: [0.7476 0.2556]
# 1/1 [==============================] - 0s 29ms/step
# Predicted coordinates: [0.7744 0.2544]
# 1/1 [==============================] - 0s 35ms/step
# Predicted coordinates: [0.641  0.2954]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.739 0.282]
# 1/1 [==============================] - 0s 60ms/step
# Predicted coordinates: [0.84  0.255]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.83   0.2461]
# 1/1 [==============================] - 0s 23ms/step
# Predicted coordinates: [0.9077 0.214 ]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99   0.1665]
# 1/1 [==============================] - 0s 25ms/step
# Predicted coordinates: [0.99    0.08264]
# 1/1 [==============================] - 0s 22ms/step
# Predicted coordinates: [0.99   0.0641]
# 1/1 [==============================] - 0s 63ms/step
# Predicted coordinates: [0.99    0.05594]
# 1/1 [==============================] - 0s 30ms/step
# Predicted coordinates: [0.99  0.043]
# 1/1 [==============================] - 0s 31ms/step
# Predicted coordinates: [0.99    0.03226]
# 1/1 [==============================] - 0s 30ms/step
# Predicted coordinates: [0.99    0.03186]
# 1/1 [==============================] - 0s 29ms/step
# Predicted coordinates: [0.99  0.031]
# 1/1 [==============================] - 0s 25ms/step
# Predicted coordinates: [0.99    0.03152]
# 1/1 [==============================] - 0s 28ms/step
# Predicted coordinates: [0.99    0.03284]
# 1/1 [==============================] - 0s 35ms/step
# Predicted coordinates: [0.99   0.0315]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99    0.03125]
# 1/1 [==============================] - 0s 35ms/step
# Predicted coordinates: [0.99    0.03186]
# 1/1 [==============================] - 0s 32ms/step
# Predicted coordinates: [0.99   0.0351]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 33ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 22ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 38ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 37ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 26ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 35ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99     0.012634]
# 1/1 [==============================] - 0s 28ms/step
# Predicted coordinates: [0.99    0.05783]
# 1/1 [==============================] - 0s 30ms/step
# Predicted coordinates: [0.99    0.04245]
# 1/1 [==============================] - 0s 48ms/step
# Predicted coordinates: [0.99    0.01117]
# 1/1 [==============================] - 0s 30ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 30ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 28ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 23ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 26ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 30ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 26ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 57ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 56ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 32ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 22ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 65ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 21ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 22ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 20ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 23ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 19ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 51ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 29ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 22ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 22ms/step
# Predicted coordinates: [0.99    0.01141]
# 1/1 [==============================] - 0s 34ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 30ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 40ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 36ms/step
# Predicted coordinates: [0.99    0.01196]
# 1/1 [==============================] - 0s 25ms/step
# Predicted coordinates: [0.99     0.013794]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99    0.01099]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99    0.01221]
# 1/1 [==============================] - 0s 25ms/step
# Predicted coordinates: [0.99    0.01257]
# 1/1 [==============================] - 0s 33ms/step
# Predicted coordinates: [0.99    0.01398]
# 1/1 [==============================] - 0s 25ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 25ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 31ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 25ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 30ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 39ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 2s 2s/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 41ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 29ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 21ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 32ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 31ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.99    0.02277]
# 1/1 [==============================] - 0s 26ms/step
# Predicted coordinates: [0.91   0.2017]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.8403 0.2217]
# 1/1 [==============================] - 0s 32ms/step
# Predicted coordinates: [0.8804 0.2068]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.91   0.1956]
# 1/1 [==============================] - 0s 54ms/step
# Predicted coordinates: [0.911 0.195]
# 1/1 [==============================] - 0s 28ms/step
# Predicted coordinates: [0.9033 0.1963]
# 1/1 [==============================] - 0s 28ms/step
# Predicted coordinates: [0.8975 0.1978]
# 1/1 [==============================] - 0s 34ms/step
# Predicted coordinates: [0.8877 0.2017]
# 1/1 [==============================] - 0s 28ms/step
# Predicted coordinates: [0.898  0.1986]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.922  0.1921]
# 1/1 [==============================] - 0s 22ms/step
# Predicted coordinates: [0.9287 0.1897]
# 1/1 [==============================] - 0s 28ms/step
# Predicted coordinates: [0.933  0.1877]
# 1/1 [==============================] - 0s 22ms/step
# Predicted coordinates: [0.9365 0.1868]
# 1/1 [==============================] - 0s 55ms/step
# Predicted coordinates: [0.941  0.1855]
# 1/1 [==============================] - 0s 34ms/step
# Predicted coordinates: [0.9434 0.1843]
# 1/1 [==============================] - 0s 60ms/step
# Predicted coordinates: [0.943  0.1843]
# 1/1 [==============================] - 0s 66ms/step
# Predicted coordinates: [0.9443 0.1833]
# 1/1 [==============================] - 0s 21ms/step
# Predicted coordinates: [0.9443 0.1829]
# 1/1 [==============================] - 0s 23ms/step
# Predicted coordinates: [0.938  0.1847]
# 1/1 [==============================] - 0s 25ms/step
# Predicted coordinates: [0.9277 0.1873]
# 1/1 [==============================] - 0s 32ms/step
# Predicted coordinates: [0.924  0.1884]
# 1/1 [==============================] - 0s 42ms/step
# Predicted coordinates: [0.9165 0.1903]
# 1/1 [==============================] - 0s 35ms/step
# Predicted coordinates: [0.9136 0.1913]
# 1/1 [==============================] - 0s 30ms/step
# Predicted coordinates: [0.9087 0.1926]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.907  0.1934]
# 1/1 [==============================] - 0s 60ms/step
# Predicted coordinates: [0.906  0.1938]
# 1/1 [==============================] - 0s 19ms/step
# Predicted coordinates: [0.908  0.1934]
# 1/1 [==============================] - 0s 54ms/step
# Predicted coordinates: [0.9126 0.1924]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.912  0.1923]
# 1/1 [==============================] - 0s 25ms/step
# Predicted coordinates: [0.9126 0.192 ]
# 1/1 [==============================] - 0s 19ms/step
# Predicted coordinates: [0.9106 0.1926]
# 1/1 [==============================] - 0s 28ms/step
# Predicted coordinates: [0.9116 0.1924]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.9155 0.1915]
# 1/1 [==============================] - 0s 22ms/step
# Predicted coordinates: [0.919  0.1904]
# 1/1 [==============================] - 0s 48ms/step
# Predicted coordinates: [0.9185 0.1902]
# 1/1 [==============================] - 0s 20ms/step
# Predicted coordinates: [0.9155 0.1912]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.9155 0.1912]
# 1/1 [==============================] - 0s 22ms/step
# Predicted coordinates: [0.909 0.193]
# 1/1 [==============================] - 0s 32ms/step
# Predicted coordinates: [0.9014 0.1953]
# 1/1 [==============================] - 0s 21ms/step
# Predicted coordinates: [0.896  0.1967]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.895  0.1969]
# 1/1 [==============================] - 0s 77ms/step
# Predicted coordinates: [0.8926 0.198 ]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.898  0.1964]
# 1/1 [==============================] - 0s 22ms/step
# Predicted coordinates: [0.894 0.198]
# 1/1 [==============================] - 0s 34ms/step
# Predicted coordinates: [0.8394 0.2142]
# 1/1 [==============================] - 0s 30ms/step
# Predicted coordinates: [0.8247 0.2196]
# 1/1 [==============================] - 0s 32ms/step
# Predicted coordinates: [0.902  0.1982]
# 1/1 [==============================] - 0s 23ms/step
# Predicted coordinates: [0.9272 0.1907]
# 1/1 [==============================] - 0s 28ms/step
# Predicted coordinates: [0.942  0.1841]
# 1/1 [==============================] - 0s 52ms/step
# Predicted coordinates: [0.941  0.1824]
# 1/1 [==============================] - 0s 22ms/step
# Predicted coordinates: [0.9443 0.1802]
# 1/1 [==============================] - 0s 24ms/step
# Predicted coordinates: [0.9463 0.1788]
# 1/1 [==============================] - 0s 25ms/step
# Predicted coordinates: [0.945  0.1786]
# 1/1 [==============================] - 0s 45ms/step
# Predicted coordinates: [0.936  0.1803]
# 1/1 [==============================] - 0s 26ms/step
# Predicted coordinates: [0.9814 0.1667]
# 1/1 [==============================] - 0s 29ms/step
# Predicted coordinates: [0.99   0.1487]
# 1/1 [==============================] - 0s 39ms/step
# Predicted coordinates: [0.99   0.1198]
# 1/1 [==============================] - 0s 39ms/step
# Predicted coordinates: [0.99   0.1123]
# 1/1 [==============================] - 0s 28ms/step
# Predicted coordinates: [0.99    0.10876]
# 1/1 [==============================] - 0s 26ms/step
# Predicted coordinates: [0.99    0.10693]
# 1/1 [==============================] - 0s 26ms/step
# Predicted coordinates: [0.99    0.10693]
# 1/1 [==============================] - 0s 28ms/step
# Predicted coordinates: [0.99    0.10913]
# 1/1 [==============================] - 0s 41ms/step
# Predicted coordinates: [0.99   0.1315]
# 1/1 [==============================] - 0s 31ms/step
# Predicted coordinates: [0.99   0.1287]
# 1/1 [==============================] - 0s 49ms/step
# Predicted coordinates: [0.99   0.1139]
# 1/1 [==============================] - 0s 40ms/step
# Predicted coordinates: [0.99  0.106]
# 1/1 [==============================] - 0s 48ms/step
# Predicted coordinates: [0.99    0.10077]
# 1/1 [==============================] - 0s 26ms/step
# Predicted coordinates: [0.99  0.093]
# 1/1 [==============================] - 0s 23ms/step
# Predicted coordinates: [0.99    0.09015]
# 1/1 [==============================] - 0s 32ms/step
# Predicted coordinates: [0.99   0.0825]
# 1/1 [==============================] - 0s 33ms/step
# Predicted coordinates: [0.99   0.0788]
# 1/1 [==============================] - 0s 26ms/step
# Predicted coordinates: [0.99    0.07837]
# 1/1 [==============================] - 0s 45ms/step
# Predicted coordinates: [0.99    0.06775]
# 1/1 [==============================] - 0s 23ms/step
# Predicted coordinates: [0.99    0.05307]
# 1/1 [==============================] - 0s 49ms/step
# Predicted coordinates: [0.99    0.06216]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99   0.1414]
# 1/1 [==============================] - 0s 28ms/step
# Predicted coordinates: [0.99   0.0492]
# 1/1 [==============================] - 0s 31ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 33ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 59ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 27ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 26ms/step
# Predicted coordinates: [0.99 0.01]
# 1/1 [==============================] - 0s 21ms/step
# Predicted coordinates: [0.99 0.01]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 77
#      74 image_expanded = np.expand_dims(image, axis=(0, 3))
#      76 # Prediction
# ---> 77 prediction = model.predict(image_expanded)
#      78 prediction = np.clip(prediction, 0.01, 0.99)
#      80 print("Predicted coordinates:", prediction[0])
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\keras\engine\training.py:2220, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2211     except ValueError:
#    2212         warnings.warn(
#    2213             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2214             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2217             stacklevel=2,
#    2218         )
# -> 2220 data_handler = data_adapter.get_data_handler(
#    2221     x=x,
#    2222     batch_size=batch_size,
#    2223     steps_per_epoch=steps,
#    2224     initial_epoch=0,
#    2225     epochs=1,
#    2226     max_queue_size=max_queue_size,
#    2227     workers=workers,
#    2228     use_multiprocessing=use_multiprocessing,
#    2229     model=self,
#    2230     steps_per_execution=self._steps_per_execution,
#    2231 )
#    2233 # Container that configures and calls `tf.keras.Callback`s.
#    2234 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\keras\engine\data_adapter.py:1582, in get_data_handler(*args, **kwargs)
#    1580 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1581     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1582 return DataHandler(*args, **kwargs)
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\keras\engine\data_adapter.py:1262, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1259     self._steps_per_execution = steps_per_execution
#    1261 adapter_cls = select_data_adapter(x, y)
# -> 1262 self._adapter = adapter_cls(
#    1263     x,
#    1264     y,
#    1265     batch_size=batch_size,
#    1266     steps=steps_per_epoch,
#    1267     epochs=epochs - initial_epoch,
#    1268     sample_weights=sample_weight,
#    1269     shuffle=shuffle,
#    1270     max_queue_size=max_queue_size,
#    1271     workers=workers,
#    1272     use_multiprocessing=use_multiprocessing,
#    1273     distribution_strategy=tf.distribute.get_strategy(),
#    1274     model=model,
#    1275 )
#    1277 strategy = tf.distribute.get_strategy()
#    1279 self._current_step = 0
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\keras\engine\data_adapter.py:349, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     345     return flat_dataset
#     347 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
# --> 349 dataset = self.slice_inputs(indices_dataset, inputs)
#     351 if shuffle == "batch":
#     353     def shuffle_batch(*batch):
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\keras\engine\data_adapter.py:390, in TensorLikeDataAdapter.slice_inputs(self, indices_dataset, inputs)
#     385 def grab_batch(i, data):
#     386     return tf.nest.map_structure(
#     387         lambda d: tf.gather(d, i, axis=0), data
#     388     )
# --> 390 dataset = dataset.map(grab_batch, num_parallel_calls=tf.data.AUTOTUNE)
#     392 # Default optimizations are disabled to avoid the overhead of
#     393 # (unnecessary) input pipeline graph serialization and deserialization
#     394 options = tf.data.Options()
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2204, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2202   return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    2203 else:
# -> 2204   return ParallelMapDataset(
#    2205       self,
#    2206       map_func,
#    2207       num_parallel_calls,
#    2208       deterministic,
#    2209       preserve_cardinality=True,
#    2210       name=name)
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:5441, in ParallelMapDataset.__init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#    5439 self._input_dataset = input_dataset
#    5440 self._use_inter_op_parallelism = use_inter_op_parallelism
# -> 5441 self._map_func = structured_function.StructuredFunctionWrapper(
#    5442     map_func,
#    5443     self._transformation_name(),
#    5444     dataset=input_dataset,
#    5445     use_legacy_function=use_legacy_function)
#    5446 if deterministic is None:
#    5447   self._deterministic = "default"
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\tensorflow\python\data\ops\structured_function.py:271, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     264       warnings.warn(
#     265           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     266           "option is set, this option does not apply to tf.data functions. "
#     267           "To force eager execution of tf.data functions, please use "
#     268           "`tf.data.experimental.enable_debug_mode()`.")
#     269     fn_factory = trace_tf_function(defun_kwargs)
# --> 271 self._function = fn_factory()
#     272 # There is no graph to add in eager mode.
#     273 add_to_graph &= not context.executing_eagerly()
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\tensorflow\python\eager\function.py:2610, in Function.get_concrete_function(self, *args, **kwargs)
#    2601 def get_concrete_function(self, *args, **kwargs):
#    2602   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#    2603
#    2604   Args:
#    (...)
#    2608        or `tf.Tensor` or `tf.TensorSpec`.
#    2609   """
# -> 2610   graph_function = self._get_concrete_function_garbage_collected(
#    2611       *args, **kwargs)
#    2612   graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    2613   return graph_function
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\tensorflow\python\eager\function.py:2576, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    2574   args, kwargs = None, None
#    2575 with self._lock:
# -> 2576   graph_function, _ = self._maybe_define_function(args, kwargs)
#    2577   seen_names = set()
#    2578   captured = object_identity.ObjectIdentitySet(
#    2579       graph_function.graph.internal_captures)
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\tensorflow\python\eager\function.py:2760, in Function._maybe_define_function(self, args, kwargs)
#    2758   # Only get placeholders for arguments, not captures
#    2759   args, kwargs = placeholder_dict["args"]
# -> 2760 graph_function = self._create_graph_function(args, kwargs)
#    2762 graph_capture_container = graph_function.graph._capture_func_lib  # pylint: disable=protected-access
#    2763 # Maintain the list of all captures
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\tensorflow\python\eager\function.py:2670, in Function._create_graph_function(self, args, kwargs)
#    2665 missing_arg_names = [
#    2666     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    2667 ]
#    2668 arg_names = base_arg_names + missing_arg_names
#    2669 graph_function = ConcreteFunction(
# -> 2670     func_graph_module.func_graph_from_py_func(
#    2671         self._name,
#    2672         self._python_function,
#    2673         args,
#    2674         kwargs,
#    2675         self.input_signature,
#    2676         autograph=self._autograph,
#    2677         autograph_options=self._autograph_options,
#    2678         arg_names=arg_names,
#    2679         capture_by_value=self._capture_by_value),
#    2680     self._function_attributes,
#    2681     spec=self.function_spec,
#    2682     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    2683     # scope. This is not the default behavior since it gets used in some
#    2684     # places (like Keras) where the FuncGraph lives longer than the
#    2685     # ConcreteFunction.
#    2686     shared_func_graph=False)
#    2687 return graph_function
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\tensorflow\python\framework\func_graph.py:1144, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1142   assert isinstance(op_return_value, ops.Tensor), op_return_value
#    1143 if func_graph is None:
# -> 1144   func_graph = FuncGraph(
#    1145       name, collections=collections, capture_by_value=capture_by_value)
#    1146 assert isinstance(func_graph, FuncGraph)
#    1147 if add_control_dependencies:
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\tensorflow\python\framework\func_graph.py:230, in FuncGraph.__init__(self, name, collections, capture_by_value, structured_input_signature, structured_outputs)
#     201 def __init__(self,
#     202              name,
#     203              collections=None,
#     204              capture_by_value=None,
#     205              structured_input_signature=None,
#     206              structured_outputs=None):
#     207   """Construct a new FuncGraph.
#     208
#     209   The graph will inherit its graph key, collections, seed, and distribution
#    (...)
#     228       information.
#     229   """
# --> 230   super(FuncGraph, self).__init__()
#     231   self.name = name
#     232   self.inputs = []
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\tensorflow\python\framework\ops.py:3214, in Graph.__init__(self)
#    3210 self._reduced_shape_cache = {}
#    3212 # TODO(skyewm): fold as much of the above as possible into the C
#    3213 # implementation
# -> 3214 self._c_graph = c_api_util.ScopedTFGraph(self._graph_key)
#    3215 # The C API requires all ops to have shape functions. Disable this
#    3216 # requirement (many custom ops do not have shape functions, and we don't
#    3217 # want to break these existing cases).
#    3218 with self._c_graph.get() as c_graph:
#
# File c:\Users\Cyril\miniconda3\envs\dev\lib\site-packages\tensorflow\python\framework\c_api_util.py:97, in ScopedTFGraph.__init__(self, name)
#      95 def __init__(self, name):
#      96   super(ScopedTFGraph, self).__init__(
# ---> 97       name, obj=c_api.TF_NewGraph(), deleter=c_api.TF_DeleteGraph)
#
# KeyboardInterrupt:
